# %% [markdown]
# # Intialize

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy_sz import Class as Class_sz
import os
import time





cosmo_params = {
'omega_b': 0.02242,
'omega_cdm':  0.11933,
'H0': 67.66, # use H0 because this is what is used by the emulators and to avoid any ambiguity when comparing with camb. 
'tau_reio': 0.0561,
'ln10^{10}A_s': 3.047,
'n_s': 0.9665
}

# %% [markdown]
# # Compute linear matter power spectrum

# %% [markdown]
# ## Method 1
#
# In this method, $P(k,z)$ is obtained by interpolating a $z$ and $k$ grid.
#
# The number of points in the $k$ dimension is fixed by the emulators settings.
#
# The number of points in the $z$ dimension is fixed by the use via the parameter `ndim_redshifts`

# %%
# %%time 
classy_sz = Class_sz()
classy_sz.set(cosmo_params)
classy_sz.set({
'output':'mPk',
'ndim_redshifts': 25
})
classy_sz.compute_class_szfast()
# Out:
# CPU times: user 55 ms, sys: 31 ms, total: 86 ms
# Wall time: 62.8 ms

# %%
z = 0.3
kmin = 1e-3
kmax = 1e1
nks = 500
ks = np.geomspace(kmin,kmax,nks)
pks = classy_sz.pk_lin(ks,z)

# %%
plt.plot(ks,pks)
plt.loglog()
# Out:
# []

# %%
plt.plot(ks,pks)
plt.loglog()
# Out:
# []

# %%
# let's time it
# %timeit -n 10 classy_sz.compute_class_szfast()
# Out:
# 36.7 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Method 2
#
# In this method, we first initialize the computation and then compute the pks.
#
# The advantage of this method is that we don't go through the Pk interpolator at each evaluation when we call
# `classy_sz.get_pkl_at_z`

# %%
# %%time
# initialize computation
classy_sz = Class_sz()
classy_sz.set(cosmo_params)
classy_sz.set({
'output':'mPk',
})
classy_sz.compute_class_szfast()
# Out:
# CPU times: user 187 ms, sys: 97.4 ms, total: 285 ms
# Wall time: 191 ms

# %%
# %%time
z = 0.3
pks,ks = classy_sz.get_pkl_at_z(z,params_values_dict = cosmo_params)
# Out:
# CPU times: user 6.68 ms, sys: 3.49 ms, total: 10.2 ms
# Wall time: 12.7 ms

# %%
plt.plot(ks,pks)
plt.loglog()
# Out:
# []

# %%
# let's time it 
# %timeit -n 10 classy_sz.get_pkl_at_z(z,params_values_dict = cosmo_params)
# Out:
# 1.55 ms ± 454 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
