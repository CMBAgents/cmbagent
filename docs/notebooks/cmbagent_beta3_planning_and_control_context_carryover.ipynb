# %% [markdown]
# # Cosmology tasks

# %%
import os
import re
# os.environ["ASTROPILOT_DISABLE_DISPLAY"] = "false"
import copy
# from astropilot import AstroPilot
# from cmbagent import CMBAgent
import cmbagent

# %%
# task = r"""
# Download the file: https://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt
# Its description is: 
# <description>
# An ASCII table with tab-separated columns: Super|nova Name, Redshift, Distance Modulus, and Distance Modulus Error. For Union2.1, there is an additional column for the probability that the supernova was hosted by a low-mass galaxy.
# </description>
# Fit this data within flat LCDM model with two free parameters: H0 and Omega_L. Write a simple MCMC (but optimized/fast) code to fit for H0 and Ω_L using the SN1a data.
# Make a contour plot and show the 1d posteriors, and quote the mean and 1-sigma on each parameter. 
# Finally show the data along with the best fit model and 68%/95% CL regions. 
# Comment on the results. 


# Constraints: 
# We are running this analysis on a Macbook Pro with 8 available threads. Ensure you use the resources optimally so the MCMC can run fast, i.e., within a few minutes until convergence.
# Have the engineer agent do a preliminary MCMC timing step in a separate step. 
# """

# task = r"""
# Describe socrate.
# """

# task = r"""
# Tell me about chaos theory and why it is important in quantitative finance. Illustrate your points with a simple code and visualization.
# """

task = r"""
plogt y=x^2 
Report on results. 
"""

# task = r"""
# Calculate the Cosmic Microwave Background (CMB) E-mode polarization power spectrum ($l(l+1)C_l^{EE}/(2\\pi)$) for a flat Lambda CDM cosmology 
# using the following parameters with CAMB:\nHubble constant ($H_0$): 67.5 km/s/Mpc\nBaryon density ($\\Omega_b h^2$): 0.022\nCold dark matter density ($\\Omega_c h^2$): 0.122\nNeutrino mass sum ($\\Sigma m_\nu$): 0.06 eV\nCurvature ($\\Omega_k$): 0\nOptical depth to reionization ($\tau$): 0.04\nScalar amplitude ($A_s$): $2 \times 10^{-9}$\nScalar spectral index ($n_s$): 0.965\n\nCompute the E-mode power spectrum ($l(l+1)C_l^{EE}/(2\\pi)$) in units of $\\mu K^2$ for multipole moments from $l=2$ to $l=3000$. Save the results in a CSV file named result.csv with two columns:\nl: Multipole moment (integer values from 2 to 3000)\nEE: E-mode polarization power spectrum ($l(l+1)C_l^{EE}/(2\\pi)$ in $\\mu K^2$) 
# """


# task = r"""
# Calculate the Cosmic Microwave Background (CMB) raw temperature power spectrum for a flat Lambda CDM cosmology using the following parameters with CAMB:
#     Hubble constant ($H_0$): 74 km/s/Mpc
#     Baryon density ($\Omega_b h^2$): 0.022
#     Cold dark matter density ($\Omega_c h^2$): 0.122
#     Neutrino mass sum ($\Sigma m_
# u$): 0.06 eV
#     Curvature ($\Omega_k$): 0
#     Optical depth to reionization ($\tau$): 0.06
#     Scalar amplitude ($A_s$): $2 \times 10^{-9}$
#     Scalar spectral index ($n_s$): 0.965

#     Compute the temperature power spectrum ($C_l^{TT}$) in units of $\mu K^2$ for multipole moments from $l=2$ to $l=3000$. Save the results in a CSV file named result.csv with two columns:
#     l: Multipole moment (integer values from 2 to 3000)
#     TT: Raw temperature power spectrum



# Visualizations are not needed for this run.
# """


results = cmbagent.planning_and_control_context_carryover(task,
                              max_rounds_control = 500,
                              n_plan_reviews = 0,
                              max_n_attempts = 2,
                              max_plan_steps=2,
                              default_llm_model = "gpt-4.1-2025-04-14",
                              engineer_model = "gemini-2.5-pro-preview-03-25",
                              camb_context_model = "gemini-2.5-pro-preview-03-25",
                              researcher_model = "gpt-4.1-2025-04-14",
                              plan_reviewer_model = "claude-3-7-sonnet-20250219",
#                               plan_instructions=r"""
# Use camb_context agent to start and then engineer agent for the whole analysis. 
# The plan must have 3 steps or more. 
# """
                              plan_instructions=r"""
Use engineer for whole analysis except in last step where you should use researcher to report on results. Plan must have 2 steps.
""",
                              restart_at_step = 1,
                             );
# Out:
# plogt y=x^2
# Report on results.
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00239            807                 97           904
#
# --------------------------------------------------------------------------------
#
# - Saved /Users/boris/CMBAgents/cmbagent/output/control/data/plot_y_equals_x_squared_1_1750280756.png
#
# - Saved /Users/boris/CMBAgents/cmbagent/output/control/data/quadratic_function_plot_1_20250618220055.png
#
# **Step number:** 1 out of 2.
#
# **Sub-task:** Analyze and plot the function y = x^2
#
# **Agent in charge of sub-task:** `engineer`
#
# **Instructions:**
#
# - Generate a suitable range of x values.
# - Compute corresponding y values using y = x^2.
# - Create a plot of y versus x.
# - Calculate and summarize any key statistics or features of the function (e.g., minimum, maximum, symmetry).
#
# **Status:** in progress ⏳
#
#
# --------------------------------------------------------------------------------
#
# Calling engineer...
#
#                        Model    agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gemini-2.5-pro-preview-03-25 engineer 0.01204           2151                935          3086
# **Code Explanation:**
#
# The code performs the following actions:
# 1.  Imports necessary libraries: `numpy` for numerical operations, `matplotlib.pyplot` for plotting, `os` for directory creation, and `time` for generating timestamps.
# 2.  Disables LaTeX rendering for matplotlib to avoid potential issues.
# 3.  Defines a directory `data/` for saving plots and creates it if it doesn't exist.
# 4.  Generates a range of x values from -10 to 10 with 100 points using `np.linspace`.
# 5.  Computes the corresponding y values using the function y = x^2.
# 6.  Creates a plot of y versus x:
#     *   Sets the figure size for better clarity.
#     *   Plots the function.
#     *   Sets an informative title, x-axis label, and y-axis label.
#     *   Adds a grid for better readability.
#     *   Ensures layout is tight to prevent labels from overlapping.
#     *   Saves the plot as a PNG file in the `data/` directory with a unique timestamped filename.
#     *   Prints a description of the saved plot to the console.
# 7.  Calculates and prints key features of the function y = x^2:
#     *   The minimum value of y (which occurs at x=0).
#     *   A statement about the symmetry of the function (it is symmetric about the y-axis).
#
# **Python Code:**
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import time
#
# # Disable LaTeX rendering
# plt.rcParams['text.usetex'] = False
#
# # --- Create data directory if it doesn't exist ---
# database_path = "data/"
# if not os.path.exists(database_path):
#     os.makedirs(database_path)
#
# # --- Generate x and y values ---
# # x values (dimensionless)
# x = np.linspace(-10, 10, 400)
# # y values (dimensionless, as x is dimensionless)
# y = x**2
#
# # --- Create the plot ---
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.plot(x, y, label='y = x^2')
# ax.set_title('Plot of the function y = x^2')
# ax.set_xlabel('x (dimensionless)')
# ax.set_ylabel('y (dimensionless)')
# ax.grid(True)
# ax.legend()
# plt.tight_layout()
#
# # --- Save the plot ---
# plot_name = 'y_equals_x_squared'
# plot_number = 1
# timestamp = int(time.time())
# filename = database_path + plot_name + '_' + str(plot_number) + '_' + str(timestamp) + '.png'
# plt.savefig(filename, dpi=300)
# print("Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as " + filename)
#
# # --- Calculate and summarize key features ---
# min_y = np.min(y)
# min_x_index = np.argmin(y)
# min_x = x[min_x_index]
#
# print("\nKey Features of the function y = x^2:")
# print("1. Minimum value:")
# print("   The minimum value of y is " + str(min_y) + ", which occurs at x = " + str(min_x) + ".")
# print("2. Symmetry:")
# print("   The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.")
# print("3. Shape:")
# print("   The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).")
# print("4. Domain and Range:")
# print("   Domain: All real numbers (-infinity, +infinity).") # x can be any real number
# print("   Range: All non-negative real numbers [0, +infinity).") # y is always greater than or equal to 0
#
# ```
#
# --------------------------------------------------------------------------------
# Preparing for execution...
#
# **Code Explanation:**
#
# The code performs the following actions:
# 1.  Imports necessary libraries: `numpy` for numerical operations, `matplotlib.pyplot` for plotting, `os` for directory creation, and `time` for generating timestamps.
# 2.  Disables LaTeX rendering for matplotlib to avoid potential issues.
# 3.  Defines a directory `data/` for saving plots and creates it if it doesn't exist.
# 4.  Generates a range of x values from -10 to 10 with 100 points using `np.linspace`.
# 5.  Computes the corresponding y values using the function y = x^2.
# 6.  Creates a plot of y versus x:
#     *   Sets the figure size for better clarity.
#     *   Plots the function.
#     *   Sets an informative title, x-axis label, and y-axis label.
#     *   Adds a grid for better readability.
#     *   Ensures layout is tight to prevent labels from overlapping.
#     *   Saves the plot as a PNG file in the `data/` directory with a unique timestamped filename.
#     *   Prints a description of the saved plot to the console.
# 7.  Calculates and prints key features of the function y = x^2:
#     *   The minimum value of y (which occurs at x=0).
#     *   A statement about the symmetry of the function (it is symmetric about the y-axis).
#
# **Python Code:**
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import time
#
# # Disable LaTeX rendering
# plt.rcParams['text.usetex'] = False
#
# # --- Create data directory if it doesn't exist ---
# database_path = "data/"
# if not os.path.exists(database_path):
#     os.makedirs(database_path)
#
# # --- Generate x and y values ---
# # x values (dimensionless)
# x = np.linspace(-10, 10, 400)
# # y values (dimensionless, as x is dimensionless)
# y = x**2
#
# # --- Create the plot ---
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.plot(x, y, label='y = x^2')
# ax.set_title('Plot of the function y = x^2')
# ax.set_xlabel('x (dimensionless)')
# ax.set_ylabel('y (dimensionless)')
# ax.grid(True)
# ax.legend()
# plt.tight_layout()
#
# # --- Save the plot ---
# plot_name = 'y_equals_x_squared'
# plot_number = 1
# timestamp = int(time.time())
# filename = database_path + plot_name + '_' + str(plot_number) + '_' + str(timestamp) + '.png'
# plt.savefig(filename, dpi=300)
# print("Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as " + filename)
#
# # --- Calculate and summarize key features ---
# min_y = np.min(y)
# min_x_index = np.argmin(y)
# min_x = x[min_x_index]
#
# print("\nKey Features of the function y = x^2:")
# print("1. Minimum value:")
# print("   The minimum value of y is " + str(min_y) + ", which occurs at x = " + str(min_x) + ".")
# print("2. Symmetry:")
# print("   The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.")
# print("3. Shape:")
# print("   The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).")
# print("4. Domain and Range:")
# print("   Domain: All real numbers (-infinity, +infinity).") # x can be any real number
# print("   Range: All non-negative real numbers [0, +infinity).") # y is always greater than or equal to 0
#
# ```
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                       agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# o3-mini-2025-01-31 engineer_response_formatter 0.00659           1580               1103          2683
# **Code Explanation:**
#
# The code performs the following actions:
# 1. Imports necessary libraries: numpy for numerical operations, matplotlib.pyplot for plotting, os for directory creation, and time for generating timestamps.
# 2. Disables LaTeX rendering for matplotlib to avoid potential issues.
# 3. Defines a directory data/ for saving plots and creates it if it doesn't exist.
# 4. Generates a range of x values from -10 to 10 with 100 points using np.linspace.
# 5. Computes the corresponding y values using the function y = x^2.
# 6. Creates a plot of y versus x:
#     * Sets the figure size for better clarity.
#     * Plots the function.
#     * Sets an informative title, x-axis label, and y-axis label.
#     * Adds a grid for better readability.
#     * Ensures layout is tight to prevent labels from overlapping.
#     * Saves the plot as a PNG file in the data/ directory with a unique timestamped filename.
#     * Prints a description of the saved plot to the console.
# 7. Calculates and prints key features of the function y = x^2:
#     * The minimum value of y (which occurs at x=0).
#     * A statement about the symmetry of the function (it is symmetric about the y-axis).
#
# **Modifications:**
#
# No modifications were made.
#
# **Python Code:**
#
# ```python
# # filename: codebase/plot_function_y_equals_x_squared.py
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import time
#
# # Disable LaTeX rendering
# plt.rcParams['text.usetex'] = False
#
# # --- Create data directory if it doesn't exist ---
# database_path = "data/"
# if not os.path.exists(database_path):
#     os.makedirs(database_path)
#
# # --- Generate x and y values ---
# # x values (dimensionless)
# x = np.linspace(-10, 10, 400)
# # y values (dimensionless, as x is dimensionless)
# y = x**2
#
# # --- Create the plot ---
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.plot(x, y, label='y = x^2')
# ax.set_title('Plot of the function y = x^2')
# ax.set_xlabel('x (dimensionless)')
# ax.set_ylabel('y (dimensionless)')
# ax.grid(True)
# ax.legend()
# plt.tight_layout()
#
# # --- Save the plot ---
# plot_name = 'y_equals_x_squared'
# plot_number = 1
# timestamp = int(time.time())
# filename = database_path + plot_name + '_' + str(plot_number) + '_' + str(timestamp) + '.png'
# plt.savefig(filename, dpi=300)
# print("Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as " + filename)
#
# # --- Calculate and summarize key features ---
# min_y = np.min(y)
# min_x_index = np.argmin(y)
# min_x = x[min_x_index]
#
# print("\nKey Features of the function y = x^2:")
# print("1. Minimum value:")
# print("   The minimum value of y is " + str(min_y) + ", which occurs at x = " + str(min_x) + ".")
# print("2. Symmetry:")
# print("   The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.")
# print("3. Shape:")
# print("   The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).")
# print("4. Domain and Range:")
# print("   Domain: All real numbers (-infinity, +infinity).")
# print("   Range: All non-negative real numbers [0, +infinity).")
#
# ```
#
# --------------------------------------------------------------------------------
# Executing...
#
#
#  code being executed....
#
# Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as data/y_equals_x_squared_1_1750280881.png
#
# Key Features of the function y = x^2:
# 1. Minimum value:
#    The minimum value of y is 0.0006281367579349097, which occurs at x = 0.025062656641603454.
# 2. Symmetry:
#    The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.
# 3. Shape:
#    The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).
# 4. Domain and Range:
#    Domain: All real numbers (-infinity, +infinity).
#    Range: All non-negative real numbers [0, +infinity).
#
#
# Execution results:
#
# Execution output:
# Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as data/y_equals_x_squared_1_1750280881.png
#
# Key Features of the function y = x^2:
# 1. Minimum value:
#    The minimum value of y is 0.0006281367579349097, which occurs at x = 0.025062656641603454.
# 2. Symmetry:
#    The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.
# 3. Shape:
#    The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).
# 4. Domain and Range:
#    Domain: All real numbers (-infinity, +infinity).
#    Range: All non-negative real numbers [0, +infinity).
#
#
# --------------------------------------------------------------------------------
#
# The executed code was:
#
# ```python
# # filename: codebase/plot_function_y_equals_x_squared.py
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# import time
#
# # Disable LaTeX rendering
# plt.rcParams['text.usetex'] = False
#
# # --- Create data directory if it doesn't exist ---
# database_path = "data/"
# if not os.path.exists(database_path):
#     os.makedirs(database_path)
#
# # --- Generate x and y values ---
# # x values (dimensionless)
# x = np.linspace(-10, 10, 400)
# # y values (dimensionless, as x is dimensionless)
# y = x**2
#
# # --- Create the plot ---
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.plot(x, y, label='y = x^2')
# ax.set_title('Plot of the function y = x^2')
# ax.set_xlabel('x (dimensionless)')
# ax.set_ylabel('y (dimensionless)')
# ax.grid(True)
# ax.legend()
# plt.tight_layout()
#
# # --- Save the plot ---
# plot_name = 'y_equals_x_squared'
# plot_number = 1
# timestamp = int(time.time())
# filename = database_path + plot_name + '_' + str(plot_number) + '_' + str(timestamp) + '.png'
# plt.savefig(filename, dpi=300)
# print("Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as " + filename)
#
# # --- Calculate and summarize key features ---
# min_y = np.min(y)
# min_x_index = np.argmin(y)
# min_x = x[min_x_index]
#
# print("\nKey Features of the function y = x^2:")
# print("1. Minimum value:")
# print("   The minimum value of y is " + str(min_y) + ", which occurs at x = " + str(min_x) + ".")
# print("2. Symmetry:")
# print("   The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.")
# print("3. Shape:")
# print("   The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).")
# print("4. Domain and Range:")
# print("   Domain: All real numbers (-infinity, +infinity).")
# print("   Range: All non-negative real numbers [0, +infinity).")
# ```
#
# ================================================
#
# The output of the executed code was:
#
# Execution results:
#
# Execution output:
# Plot saved: A plot of the function y = x^2, showing a parabola opening upwards, symmetric about the y-axis. Saved as data/y_equals_x_squared_1_1750280881.png
#
# Key Features of the function y = x^2:
# 1. Minimum value:
#    The minimum value of y is 0.0006281367579349097, which occurs at x = 0.025062656641603454.
# 2. Symmetry:
#    The function y = x^2 is symmetric about the y-axis. This means f(x) = f(-x). For example, f(2) = 4 and f(-2) = 4.
# 3. Shape:
#    The graph of y = x^2 is a parabola opening upwards with its vertex at the origin (0,0).
# 4. Domain and Range:
#    Domain: All real numbers (-infinity, +infinity).
#    Range: All non-negative real numbers [0, +infinity).
#
#
# ================================================
#
#
# --------------------------------------------------------------------------------
# Selecting next agent based on execution result...
#
#              Model                       agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# o3-mini-2025-01-31 executor_response_formatter 0.00184           1267                101          1368
#
# --------------------------------------------------------------------------------
# Execution status: success. Transfer to control.
#
# xxxxxxxxxxxxxxxxxxxxxxxxxx
#
# Workflow status:
#
# Plan step number: 1
#
# Agent for sub-task (might be different from the next agent suggestion for debugging): engineer
#
# Current status (before execution): in progress
#
# xxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00633           2780                 96          2876
#
# --------------------------------------------------------------------------------
#
# - Saved /Users/boris/CMBAgents/cmbagent/output/control/data/y_equals_x_squared_1_1750280881.png
#
# **Step number:** 1 out of 2.
#
# **Sub-task:** Analyze and plot the function y = x^2
#
# **Agent in charge of sub-task:** `engineer`
#
# **Instructions:**
#
# - Generate a suitable range of x values.
# - Compute corresponding y values using y = x^2.
# - Create a plot of y versus x.
# - Calculate and summarize any key statistics or features of the function (e.g., minimum, maximum, symmetry).
#
# **Status:** completed ✅
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00664           2998                 80          3078
#
# --------------------------------------------------------------------------------
#
# **Step number:** 2 out of 2.
#
# **Sub-task:** Report and interpret the results of the analysis and plot
#
# **Agent in charge of sub-task:** `researcher`
#
# **Instructions:**
#
# - Discuss the characteristics and significance of the plotted function y = x^2.
# - Interpret the key statistics and features identified by the engineer.
# - Provide context or implications of the results.
#
# **Status:** in progress ⏳
#
#
# --------------------------------------------------------------------------------
# Terminating...
#
#              Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 terminator 0.00484           2416                  1          2417
#
# --------------------------------------------------------------------------------
# Session terminated.
#
# --------------------------------------------------------------------------------
#
# Timing report data saved to: /Users/boris/CMBAgents/cmbagent/output/control/time/timing_report_step_1_20250618_220809.json
#
#
# Displaying cost…
#
# | Agent                       | Cost ($)    | Prompt Tokens | Completion Tokens | Total Tokens |
# |:----------------------------|------------:|--------------:|------------------:|-------------:|
# | executor response formatter | $0.00183810 |          1267 |               101 |         1368 |
# | engineer response formatter | $0.00659120 |          1580 |              1103 |         2683 |
# | terminator                  | $0.00484000 |          2416 |                 1 |         2417 |
# | control                     | $0.01535400 |          6585 |               273 |         6858 |
# | engineer                    | $0.01203875 |          2151 |               935 |         3086 |
# |-----------------------------|-------------|---------------|-------------------|--------------|
# | Total                       | $0.04066205 |         13999 |              2413 |        16412 |
#
# Cost report data saved to: /Users/boris/CMBAgents/cmbagent/output/control/cost/cost_report_step_1_20250618_220809.json
#
#
# plogt y=x^2
# Report on results.
#
#
# --------------------------------------------------------------------------------
#
# Calling control_starter...
#
#              Model           agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control_starter 0.00099            492                  1           493
#
# --------------------------------------------------------------------------------
#
# **Step number:** 2 out of 2.
#
# **Sub-task:** Report and interpret the results of the analysis and plot
#
# **Agent in charge of sub-task:** `researcher`
#
# **Instructions:**
#
# - Discuss the characteristics and significance of the plotted function y = x^2.
# - Interpret the key statistics and features identified by the engineer.
# - Provide context or implications of the results.
#
# **Status:** in progress ⏳
#
#
# --------------------------------------------------------------------------------
#
# Calling researcher...
#
#              Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 researcher 0.00908           1392                787          2179
# # Analysis and Interpretation of the Function y = x²
#
# ## 1. Characteristics of the Function
#
# The function \( y = x^2 \) is a classic example of a quadratic function, and its graph is a parabola opening upwards. The analysis and plot generated in the previous step confirm several fundamental properties:
#
# - **Shape and Symmetry:**
#   The plot displays a symmetric parabola with respect to the y-axis. This symmetry arises because the function is even, satisfying \( f(x) = f(-x) \) for all \( x \). The vertex of the parabola is located at the origin (0, 0), which is the minimum point of the function.
#
# - **Domain and Range:**
#   The domain of \( y = x^2 \) is all real numbers (\( -\infty < x < \infty \)), as any real value of \( x \) can be squared. The range, however, is restricted to all non-negative real numbers (\( 0 \leq y < \infty \)), since squaring any real number cannot yield a negative result.
#
# - **Minimum Value:**
#   The minimum value of \( y \) is at the vertex, where \( x = 0 \). The computed minimum in the sampled data is approximately 0.0006 at \( x \approx 0.025 \), which is a result of the discrete sampling of \( x \) values. In the continuous case, the true minimum is exactly 0 at \( x = 0 \).
#
# - **Growth Behavior:**
#   As \( |x| \) increases, \( y \) increases quadratically. This means that for large values of \( |x| \), the function grows much faster than a linear function.
#
# ## 2. Interpretation of Key Features
#
# - **Symmetry:**
#   The even symmetry of the function is significant in both mathematical analysis and applications. It implies that the behavior of the function for negative values of \( x \) mirrors that for positive values, which is important in physics (e.g., potential energy functions) and engineering (e.g., signal processing).
#
# - **Vertex and Minimum:**
#   The vertex at the origin represents the global minimum of the function. This property is often exploited in optimization problems, where finding the minimum of a quadratic function is a common task.
#
# - **Unbounded Growth:**
#   The function does not have a maximum; as \( x \) moves away from zero in either direction, \( y \) increases without bound. This property is relevant in contexts where quadratic growth models phenomena such as energy, cost, or error.
#
# ## 3. Context and Implications
#
# - **Mathematical Significance:**
#   The function \( y = x^2 \) serves as a foundational example in algebra, calculus, and analysis. Its properties are used to introduce concepts such as derivatives (the slope at any point is \( 2x \)), integrals, and the study of convexity.
#
# - **Applications:**
#   Quadratic functions model a wide range of real-world phenomena, including projectile motion in physics, cost functions in economics, and error surfaces in machine learning. The upward-opening parabola is particularly important in optimization, as it guarantees a single global minimum.
#
# - **Visualization:**
#   The generated plot visually reinforces these properties, providing an intuitive understanding of the function's behavior. The clear symmetry and the shape of the parabola are immediately apparent, aiding in both teaching and analysis.
#
# ## 4. Summary
#
# The analysis and plot of \( y = x^2 \) confirm its well-known mathematical properties: symmetry about the y-axis, a global minimum at the origin, and unbounded quadratic growth. These features make it a central object of study in mathematics and its applications, and the visualization provides a clear and accessible representation of these characteristics.
#
# --------------------------------------------------------------------------------
# Formatting...
#
#              Model                         agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# o3-mini-2025-01-31 researcher_response_formatter 0.00595           1097               1078          2175
# **Markdown:**
#
# ```markdown
# <!-- filename: quadratic_analysis.md -->
# # Analysis and Interpretation of the Function y = x²
#
# ## 1. Characteristics of the Function
#
# The function \( y = x^2 \) is a classic example of a quadratic function, and its graph is a parabola opening upwards. The analysis and plot generated in the previous step confirm several fundamental properties:
#
# - **Shape and Symmetry:**
#   The plot displays a symmetric parabola with respect to the y-axis. This symmetry arises because the function is even, satisfying \( f(x) = f(-x) \) for all \( x \). The vertex of the parabola is located at the origin (0, 0), which is the minimum point of the function.
#
# - **Domain and Range:**
#   The domain of \( y = x^2 \) is all real numbers (\( -\infty < x < \infty \)), as any real value of \( x \) can be squared. The range, however, is restricted to all non-negative real numbers (\( 0 \leq y < \infty \)), since squaring any real number cannot yield a negative result.
#
# - **Minimum Value:**
#   The minimum value of \( y \) is at the vertex, where \( x = 0 \). The computed minimum in the sampled data is approximately 0.0006 at \( x \approx 0.025 \), which is a result of the discrete sampling of \( x \) values. In the continuous case, the true minimum is exactly 0 at \( x = 0 \).
#
# - **Growth Behavior:**
#   As \( |x| \) increases, \( y \) increases quadratically. This means that for large values of \( |x| \), the function grows much faster than a linear function.
#
# ## 2. Interpretation of Key Features
#
# - **Symmetry:**
#   The even symmetry of the function is significant in both mathematical analysis and applications. It implies that the behavior of the function for negative values of \( x \) mirrors that for positive values, which is important in physics (e.g., potential energy functions) and engineering (e.g., signal processing).
#
# - **Vertex and Minimum:**
#   The vertex at the origin represents the global minimum of the function. This property is often exploited in optimization problems, where finding the minimum of a quadratic function is a common task.
#
# - **Unbounded Growth:**
#   The function does not have a maximum; as \( x \) moves away from zero in either direction, \( y \) increases without bound. This property is relevant in contexts where quadratic growth models phenomena such as energy, cost, or error.
#
# ## 3. Context and Implications
#
# - **Mathematical Significance:**
#   The function \( y = x^2 \) serves as a foundational example in algebra, calculus, and analysis. Its properties are used to introduce concepts such as derivatives (the slope at any point is \( 2x \)), integrals, and the study of convexity.
#
# - **Applications:**
#   Quadratic functions model a wide range of real-world phenomena, including projectile motion in physics, cost functions in economics, and error surfaces in machine learning. The upward-opening parabola is particularly important in optimization, as it guarantees a single global minimum.
#
# - **Visualization:**
#   The generated plot visually reinforces these properties, providing an intuitive understanding of the function's behavior. The clear symmetry and the shape of the parabola are immediately apparent, aiding in both teaching and analysis.
#
# ## 4. Summary
#
# The analysis and plot of \( y = x^2 \) confirm its well-known mathematical properties: symmetry about the y-axis, a global minimum at the origin, and unbounded quadratic growth. These features make it a central object of study in mathematics and its applications, and the visualization provides a clear and accessible representation of these characteristics.
# ```
#
# --------------------------------------------------------------------------------
# Saving report...
#
# Execution results:
#
# Execution output: Content saved to /Users/boris/CMBAgents/cmbagent/output/control/quadratic_analysis.md
#
#
# --------------------------------------------------------------------------------
#
# Calling control...
#
#              Model   agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 control 0.00738           3376                 79          3455
#
# --------------------------------------------------------------------------------
#
# **Step number:** 2 out of 2.
#
# **Sub-task:** Report and interpret the results of the analysis and plot
#
# **Agent in charge of sub-task:** `researcher`
#
# **Instructions:**
#
# - Discuss the characteristics and significance of the plotted function y = x^2.
# - Interpret the key statistics and features identified by the engineer.
# - Provide context or implications of the results.
#
# **Status:** completed ✅
#
#
# --------------------------------------------------------------------------------
# Terminating...
#
#              Model      agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 terminator 0.00407           2033                  1          2034
#
# --------------------------------------------------------------------------------
# Session terminated.
#
# --------------------------------------------------------------------------------
#
# Timing report data saved to: /Users/boris/CMBAgents/cmbagent/output/control/time/timing_report_step_2_20250618_220840.json
#
#
# Displaying cost…
#
# | Agent                         | Cost ($)    | Prompt Tokens | Completion Tokens | Total Tokens |
# |:------------------------------|------------:|--------------:|------------------:|-------------:|
# | researcher response formatter | $0.00594990 |          1097 |              1078 |         2175 |
# | terminator                    | $0.00407400 |          2033 |                 1 |         2034 |
# | control starter               | $0.00099200 |           492 |                 1 |          493 |
# | researcher                    | $0.00908000 |          1392 |               787 |         2179 |
# | control                       | $0.00738400 |          3376 |                79 |         3455 |
# |-------------------------------|-------------|---------------|-------------------|--------------|
# | Total                         | $0.02747990 |          8390 |              1946 |        10336 |
#
# Cost report data saved to: /Users/boris/CMBAgents/cmbagent/output/control/cost/cost_report_step_2_20250618_220840.json

# %%
import pickle
path_context = "/Users/boris/CMBAgents/cmbagent/output/context/context_step_0.pkl"
with open(path_context, 'rb') as f:
    context = pickle.load(f)

# %%
context['cost_dataframe']
# Out:
#                             Agent  Cost ($)  Prompt Tokens  Completion Tokens  \
# 0      planner response formatter  0.001972          426.0              140.0
# 1                         planner  0.002278          471.0              167.0
# 2                      terminator  0.001416          704.0                1.0
# 3                   plan recorder  0.002536          480.0              197.0
# 4                     plan setter  0.000548          230.0               11.0
# Total                       Total  0.008750         2311.0              516.0
#
#        Total Tokens
# 0             566.0
# 1             638.0
# 2             705.0
# 3             677.0
# 4             241.0
# Total        2827.0

# %%
results['final_context']['cost_dataframe']
# Out:
#                                Agent  Cost ($)  Prompt Tokens  \
# 0      researcher response formatter  0.005390         1100.0
# 1                         terminator  0.004086         2039.0
# 2                    control starter  0.000998          495.0
# 3                         researcher  0.009392         1536.0
# 4                            control  0.007684         3526.0
# Total                          Total  0.027550         8696.0
#
#        Completion Tokens  Total Tokens
# 0                  950.0        2050.0
# 1                    1.0        2040.0
# 2                    1.0         496.0
# 3                  790.0        2326.0
# 4                   79.0        3605.0
# Total             1821.0       10517.0

# %%
# print(results['final_context']['previous_steps_execution_summary'])

# %%
# results['chat_history']

# %%
# agent_for_step = "engineer"
# for msg in results['chat_history'][::-1]:
#     if msg['name'] == agent_for_step or msg['name'] == f"{agent_for_step}_nest":
#         print(msg['content'])
#         break

# %%
results['final_context']

# %%
results['final_context']['max_n_attempts']
# Out:
# 4

# %%
results['final_context']['n_attempts']
# Out:
# 1

# %%
results['final_context']['current_plan_step_number']
# Out:
# 2

# %%
results['final_context']['number_of_steps_in_plan']
# Out:
# 7

# %%
results['final_context']['current_status']
# Out:
# 'in progress'

# %%
results['final_context']['database_path']
# Out:
# 'data/'

# %%
results['final_context']['work_dir']
# Out:
# PosixPath('/Users/boris/CMBAgents/cmbagent/output/control')

# %%
# results

# %%
# results['final_context']['final_plan']
