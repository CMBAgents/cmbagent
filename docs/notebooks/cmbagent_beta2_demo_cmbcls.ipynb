# %% [markdown]
# ## Initialize

# %%
from cmbagent import CMBAgent

cmbagent = CMBAgent()
# Out:
#  _____ ___  _________  ___  _____  _____ _   _ _____
# /  __ \|  \/  || ___ \/ _ \|  __ \|  ___| \ | |_   _|
# | /  \/| .  . || |_/ / /_\ \ |  \/| |__ |  \| | | |
# | |    | |\/| || ___ \  _  | | __ |  __|| . ` | | |
# | \__/\| |  | || |_/ / | | | |_\ \| |___| |\  | | |
#  \____/\_|  |_/\____/\_| |_/\____/\____/\_| \_/ \_/
#     multi-agent systems for autonomous discovery
#
# Version: Beta2
# Last updated: 11/03/5202
# Contributors: B. Bolliet, M. Cranmer, S. Krippendorf,
# A. Laverick, J. Lesgourgues, A. Lewis, B. D. Sherwin,
# K. M. Surrao, F. Villaescusa-Navarro, L. Xu, I. Zubeldia

# %% [markdown]
# ## Solve

# %%
task = r"""
Task: Compute and plot cmb temperature cls. 
Present a gif plot with varying ns and omega_cdm (use a 5-sigma range around planck best-fit). 
Use log scale for x and y axis. Report on results.
"""

cmbagent.solve(task,
               max_rounds=500,
               shared_context = {'feedback_left': 1,
                                 'maximum_number_of_steps_in_plan': 3})
# Out:
# Message from admin:
# Task: Compute and plot cmb temperature cls.
# Present a gif plot with varying ns and omega_cdm (use a 5-sigma range around planck best-fit).
# Use log scale for x and y axis. Report on results.
# Calling planner...
# <style type="text/css">
# </style>
# <table id="T_d9886">
#   <thead>
#     <tr>
#       <th id="T_d9886_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d9886_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_d9886_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_d9886_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_d9886_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_d9886_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9886_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
# ...
