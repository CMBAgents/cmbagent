# %% [markdown]
# *Check the interactive plots generetad by this sessions:*
#
#   A. [consumer_decision_patterns_good1.html](http://borisbolliet.github.io/Attachements/consumer_decision_patterns_good1.html)
#
#   B. [consumer_decision_patterns_good2.html](http://borisbolliet.github.io/Attachements/consumer_decision_patterns_good2.html)
#
#   C. [estimated_utility_function.html](http://borisbolliet.github.io/Attachements/estimated_utility_function.html)

# %% [markdown]
# ## Initialize

# %%
from cmbagent import CMBAgent
import os
cmbagent = CMBAgent(agent_llm_configs = {'engineer': {
                        "model": "gpt-4.5-preview-2025-02-27",
                        "api_key": os.getenv("OPENAI_API_KEY"),
                        "api_type": "openai",
                        }})
# Out:
#  _____ ___  _________  ___  _____  _____ _   _ _____
# /  __ \|  \/  || ___ \/ _ \|  __ \|  ___| \ | |_   _|
# | /  \/| .  . || |_/ / /_\ \ |  \/| |__ |  \| | | |
# | |    | |\/| || ___ \  _  | | __ |  __|| . ` | | |
# | \__/\| |  | || |_/ / | | | |_\ \| |___| |\  | | |
#  \____/\_|  |_/\____/\_| |_/\____/\____/\_| \_/ \_/
#     multi-agent systems for autonomous discovery
#
# Version: Beta2
# Last updated: 11/03/5202
# Contributors: B. Bolliet, M. Cranmer, S. Krippendorf,
# A. Laverick, J. Lesgourgues, A. Lewis, B. D. Sherwin,
# K. M. Surrao, F. Villaescusa-Navarro, L. Xu, I. Zubeldia

# %% [markdown]
# ## Solve

# %%
task = r"""
Task: Uncovering Utility Functions with Observational Data

Objective:
Develop an analytical pipeline to estimate individual utility functions from observational data capturing consumer behavior. 
The solution should process simulated data representing consumers choosing among various goods under differing income levels and price conditions, 
mirroring market dynamics in an economy similar to the New York City Area.

Key steps include:
- Data preprocessing and cleaning
- Econometric modeling to estimate utility functions
- Visualization of estimated utility functions and consumer decision patterns

Do not implement API endpoints or use Flask; instead, provide standalone visualizations.
"""

cmbagent.solve(task,
               max_rounds=500,
               shared_context = {'feedback_left': 1,
                                 'maximum_number_of_steps_in_plan': 4})
# Out:
# Message from admin:
# Task: Uncovering Utility Functions with Observational Data
#
# Objective:
# Develop an analytical pipeline to estimate individual utility functions from observational data capturing consumer behavior.
# The solution should process simulated data representing consumers choosing among various goods under differing income levels and price conditions,
# mirroring market dynamics in an economy similar to the New York City Area.
#
# Key steps include:
# - Data preprocessing and cleaning
# - Econometric modeling to estimate utility functions
# - Visualization of estimated utility functions and consumer decision patterns
#
# Do not implement API endpoints or use Flask; instead, provide standalone visualizations.
# Calling planner...
# <style type="text/css">
# </style>
# <table id="T_ed7fc">
#   <thead>
#     <tr>
#       <th id="T_ed7fc_level0_col0" class="col_heading level0 col0" >Model</th>
# ...

# %% [markdown]
# ## Context

# %%
cmbagent.final_context
# Out:
# {'plans': ["**PLAN**\n\n- Step 1:\n\t* sub-task: Data preprocessing and cleaning\n\t* agent in charge: engineer\n\n\t* instructions:\n\t\t- Load the simulated consumer behavior data.\n\t\t- Identify and handle missing values or outliers in the dataset.\n\t\t- Normalize or standardize the data as necessary to prepare for analysis.\n\t\t- Ensure the data is structured appropriately for econometric modeling.\n\n- Step 2:\n\t* sub-task: Econometric modeling to estimate utility functions\n\t* agent in charge: researcher\n\n\t* instructions:\n\t\t- Develop a theoretical framework for utility functions based on consumer choice theory.\n\t\t- Formulate the econometric model to estimate the utility functions from the cleaned data.\n\t\t- Provide mathematical proofs or reasoning to support the chosen model.\n\t\t- Document the model in markdown format for clarity and future reference.\n\n- Step 3:\n\t* sub-task: Implementation of the econometric model\n\t* agent in charge: engineer\n\n\t* inst
# ...
