# %% [markdown]
# ## Initialize

# %%
from cmbagent import CMBAgent

cmbagent = CMBAgent()
# Out:
#  _____ ___  _________  ___  _____  _____ _   _ _____
# /  __ \|  \/  || ___ \/ _ \|  __ \|  ___| \ | |_   _|
# | /  \/| .  . || |_/ / /_\ \ |  \/| |__ |  \| | | |
# | |    | |\/| || ___ \  _  | | __ |  __|| . ` | | |
# | \__/\| |  | || |_/ / | | | |_\ \| |___| |\  | | |
#  \____/\_|  |_/\____/\_| |_/\____/\____/\_| \_/ \_/
#     multi-agent systems for autonomous discovery
#
# Version: Beta2
# Last updated: 11/03/5202
# Contributors: B. Bolliet, M. Cranmer, S. Krippendorf,
# A. Laverick, J. Lesgourgues, A. Lewis, B. D. Sherwin,
# K. M. Surrao, F. Villaescusa-Navarro, L. Xu, I. Zubeldia

# %% [markdown]
# ## Solve

# %%
task = r"""
Develop and Train neural nets for the linear matter power spectrum using 2 different architectures that you think would work well.
We need the networks to be very accurate and precise, but also we want them to be fast to evaluate. 
Use log(pk) for training the networks. 
Use 500 spectra for training set and 50 for testing set.
Proceed sequentially, one architecture at a time. 
Report on what is the best architecture.
Plot predicted vs true Pks (use log scales in both x and y axes).
"""
cmbagent.solve(task,
               max_rounds=100,
               shared_context = {'feedback_left': 1,
                                 'maximum_number_of_steps_in_plan': 5})
# Out:
# Message from admin:
# Develop and Train neural nets for the linear matter power spectrum using 2 different architectures that you think would work well.
# We need the networks to be very accurate and precise, but also we want them to be fast to evaluate.
# Use log(pk) for training the networks.
# Use 500 spectra for training set and 50 for testing set.
# Proceed sequentially, one architecture at a time.
# Report on what is the best architecture.
# Plot predicted vs true Pks (use log scales in both x and y axes).
# Calling planner...
# <style type="text/css">
# </style>
# <table id="T_adf9a">
#   <thead>
#     <tr>
#       <th id="T_adf9a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_adf9a_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_adf9a_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_adf9a_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_adf9a_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_adf9a_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_adf9a_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_adf9a_row0_col1" class="data row0 col1" >planner</td>
#       <td id="T_adf9a_row0_col2" class="data row0 col2" >0.00587</td>
#       <td id="T_adf9a_row0_col3" class="data row0 col3" >494</td>
#       <td id="T_adf9a_row0_col4" class="data row0 col4" >463</td>
#       <td id="T_adf9a_row0_col5" class="data row0 col5" >957</td>
#     </tr>
#   </tbody>
# </table>
# Message from planner:
# Forwarding content for formatting...
# Calling planner_response_formatter...
# <style type="text/css">
# </style>
# <table id="T_a4b4b">
#   <thead>
#     <tr>
#       <th id="T_a4b4b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a4b4b_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_a4b4b_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_a4b4b_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_a4b4b_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_a4b4b_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a4b4b_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_a4b4b_row0_col1" class="data row0 col1" >planner_response_formatter</td>
#       <td id="T_a4b4b_row0_col2" class="data row0 col2" >0.00035</td>
#       <td id="T_a4b4b_row0_col3" class="data row0 col3" >757</td>
#       <td id="T_a4b4b_row0_col4" class="data row0 col4" >401</td>
#       <td id="T_a4b4b_row0_col5" class="data row0 col5" >1158</td>
#     </tr>
#   </tbody>
# </table>
# Message from planner_response_formatter:
# **PLAN**
#
# - Step 1:
# 	* sub-task: Gather information on the classy_sz package and its potential use for generating the linear matter power spectrum.
# 	* agent in charge: classy_sz_agent
#
# 	* instructions:
# 		- Search for information on the classy_sz package to understand its capabilities and how it can be used to generate the linear matter power spectrum.
# 		- Identify if it can be used to generate the training and testing datasets (500 spectra for training and 50 for testing).
# 		- Provide a summary of findings and any relevant implementation details.
#
# - Step 2:
# 	* sub-task: Generate the training and testing datasets for the linear matter power spectrum.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Use the classy_sz package (or an alternative if necessary) to generate 500 spectra for training and 50 spectra for testing.
# 		- Ensure the data is in the form of log(pk) for training purposes.
# 		- Save the datasets in a format suitable for training neural networks.
#
# - Step 3:
# 	* sub-task: Design and train the first neural network architecture.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Propose and implement a neural network architecture that is expected to be accurate, precise, and fast to evaluate.
# 		- Train the network using the training dataset and validate it using the testing dataset.
# 		- Evaluate the performance of the network and save the results.
#
# - Step 4:
# 	* sub-task: Design and train the second neural network architecture.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Propose and implement a second neural network architecture with a different design from the first.
# 		- Train the network using the same training dataset and validate it using the testing dataset.
# 		- Evaluate the performance of the network and save the results.
#
# - Step 5:
# 	* sub-task: Compare the two architectures and visualize the results.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Compare the performance of the two architectures in terms of accuracy, precision, and evaluation speed.
# 		- Plot the predicted vs true power spectra (log scales for both x and y axes) for both architectures.
# 		- Report on the best architecture and provide insights into its performance.
# Calling plan_recorder...
# <style type="text/css">
# </style>
# <table id="T_bc712">
#   <thead>
#     <tr>
#       <th id="T_bc712_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bc712_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_bc712_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_bc712_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_bc712_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_bc712_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc712_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_bc712_row0_col1" class="data row0 col1" >plan_recorder</td>
#       <td id="T_bc712_row0_col2" class="data row0 col2" >0.00052</td>
#       <td id="T_bc712_row0_col3" class="data row0 col3" >1307</td>
#       <td id="T_bc712_row0_col4" class="data row0 col4" >536</td>
#       <td id="T_bc712_row0_col5" class="data row0 col5" >1843</td>
#     </tr>
#   </tbody>
# </table>
# Message from plan_recorder:
# Plan has been logged.
# Calling plan_reviewer...
# <style type="text/css">
# </style>
# <table id="T_0d3ad">
#   <thead>
#     <tr>
#       <th id="T_0d3ad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0d3ad_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_0d3ad_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_0d3ad_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_0d3ad_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_0d3ad_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0d3ad_row0_col0" class="data row0 col0" >claude-3-7-sonnet-20250219</td>
#       <td id="T_0d3ad_row0_col1" class="data row0 col1" >plan_reviewer</td>
#       <td id="T_0d3ad_row0_col2" class="data row0 col2" >0.01025</td>
#       <td id="T_0d3ad_row0_col3" class="data row0 col3" >2336</td>
#       <td id="T_0d3ad_row0_col4" class="data row0 col4" >216</td>
#       <td id="T_0d3ad_row0_col5" class="data row0 col5" >2552</td>
#     </tr>
#   </tbody>
# </table>
# Message from plan_reviewer:
# Forwarding content for formatting...
# Calling reviewer_response_formatter...
# <style type="text/css">
# </style>
# <table id="T_c14d8">
#   <thead>
#     <tr>
#       <th id="T_c14d8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c14d8_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_c14d8_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_c14d8_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_c14d8_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_c14d8_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c14d8_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_c14d8_row0_col1" class="data row0 col1" >reviewer_response_formatter</td>
#       <td id="T_c14d8_row0_col2" class="data row0 col2" >0.00040</td>
#       <td id="T_c14d8_row0_col3" class="data row0 col3" >1923</td>
#       <td id="T_c14d8_row0_col4" class="data row0 col4" >188</td>
#       <td id="T_c14d8_row0_col5" class="data row0 col5" >2111</td>
#     </tr>
#   </tbody>
# </table>
# Message from reviewer_response_formatter:
# **Recommendations:**
#
# - Involve the researcher in Step 1 to provide theoretical background on the linear matter power spectrum and neural network approaches that have been successful in cosmology applications. This will help guide the architecture design in later steps.
#
# - Modify Step 2 to include more specific instructions for the engineer about parameter space sampling for generating the power spectra, ensuring sufficient diversity in the training and testing datasets.
#
# - Revise Step 3 to include specific evaluation metrics for the neural networks (e.g., mean squared error, maximum relative error) to ensure proper assessment of accuracy and precision.
#
# - Update Step 4 to ensure the second architecture is sufficiently different from the first one, perhaps suggesting specific alternative approaches (e.g., if the first is a CNN, the second could be a transformer or MLP).
#
# - Enhance Step 5 to include benchmarking of inference speed for both architectures, as this is mentioned as an important requirement in the task description.
# Calling review_recorder...
# <style type="text/css">
# </style>
# <table id="T_d37b4">
#   <thead>
#     <tr>
#       <th id="T_d37b4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d37b4_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_d37b4_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_d37b4_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_d37b4_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_d37b4_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d37b4_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_d37b4_row0_col1" class="data row0 col1" >review_recorder</td>
#       <td id="T_d37b4_row0_col2" class="data row0 col2" >0.00044</td>
#       <td id="T_d37b4_row0_col3" class="data row0 col3" >2111</td>
#       <td id="T_d37b4_row0_col4" class="data row0 col4" >204</td>
#       <td id="T_d37b4_row0_col5" class="data row0 col5" >2315</td>
#     </tr>
#   </tbody>
# </table>
# Message from review_recorder:
# Recommendations have been logged.
# Number of feedback rounds left: 0.
# Now, update the plan accordingly, planner!
# Calling planner...
# <style type="text/css">
# </style>
# <table id="T_8bfda">
#   <thead>
#     <tr>
#       <th id="T_8bfda_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8bfda_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_8bfda_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_8bfda_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_8bfda_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_8bfda_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bfda_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_8bfda_row0_col1" class="data row0 col1" >planner</td>
#       <td id="T_8bfda_row0_col2" class="data row0 col2" >0.01920</td>
#       <td id="T_8bfda_row0_col3" class="data row0 col3" >3357</td>
#       <td id="T_8bfda_row0_col4" class="data row0 col4" >1081</td>
#       <td id="T_8bfda_row0_col5" class="data row0 col5" >4438</td>
#     </tr>
#   </tbody>
# </table>
# Message from planner:
# Forwarding content for formatting...
# Calling planner_response_formatter...
# <style type="text/css">
# </style>
# <table id="T_92b98">
#   <thead>
#     <tr>
#       <th id="T_92b98_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_92b98_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_92b98_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_92b98_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_92b98_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_92b98_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_92b98_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_92b98_row0_col1" class="data row0 col1" >planner_response_formatter</td>
#       <td id="T_92b98_row0_col2" class="data row0 col2" >0.00114</td>
#       <td id="T_92b98_row0_col3" class="data row0 col3" >3864</td>
#       <td id="T_92b98_row0_col4" class="data row0 col4" >942</td>
#       <td id="T_92b98_row0_col5" class="data row0 col5" >4806</td>
#     </tr>
#   </tbody>
# </table>
# Message from planner_response_formatter:
# **PLAN**
#
# - Step 1:
# 	* sub-task: Provide theoretical background on the linear matter power spectrum and neural network approaches in cosmology.
# 	* agent in charge: researcher
#
# 	* instructions:
# 		- Summarize the theoretical background of the linear matter power spectrum.
# 		- Review neural network architectures that have been successful in cosmology applications.
# 		- Provide guidance on potential architectures to consider for this task.
#
# - Step 2:
# 	* sub-task: Gather information on the classy_sz package and its potential use for generating the linear matter power spectrum.
# 	* agent in charge: classy_sz_agent
#
# 	* instructions:
# 		- Search for information on the classy_sz package to understand its capabilities and how it can be used to generate the linear matter power spectrum.
# 		- Identify if it can be used to generate the training and testing datasets (500 spectra for training and 50 for testing).
# 		- Provide a summary of findings and any relevant implementation details.
#
# - Step 3:
# 	* sub-task: Generate the training and testing datasets for the linear matter power spectrum.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Use the classy_sz package (or an alternative if necessary) to generate 500 spectra for training and 50 spectra for testing.
# 		- Ensure sufficient diversity in the datasets by sampling the parameter space effectively.
# 		- Ensure the data is in the form of log(pk) for training purposes.
# 		- Save the datasets in a format suitable for training neural networks.
#
# - Step 4:
# 	* sub-task: Design and train the first neural network architecture.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Propose and implement a neural network architecture that is expected to be accurate, precise, and fast to evaluate.
# 		- Train the network using the training dataset and validate it using the testing dataset.
# 		- Evaluate the performance of the network using metrics such as mean squared error and maximum relative error.
# 		- Save the results and trained model.
#
# - Step 5:
# 	* sub-task: Design and train the second neural network architecture.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Propose and implement a second neural network architecture with a sufficiently different design from the first (e.g., if the first is a CNN, the second could be a transformer or MLP).
# 		- Train the network using the same training dataset and validate it using the testing dataset.
# 		- Evaluate the performance of the network using metrics such as mean squared error and maximum relative error.
# 		- Save the results and trained model.
#
# - Step 6:
# 	* sub-task: Compare the two architectures and visualize the results.
# 	* agent in charge: engineer
#
# 	* instructions:
# 		- Compare the performance of the two architectures in terms of accuracy, precision, and evaluation speed.
# 		- Benchmark the inference speed for both architectures.
# 		- Plot the predicted vs true power spectra (log scales for both x and y axes) for both architectures.
# 		- Report on the best architecture and provide insights into its performance.
# Calling plan_recorder...
# <style type="text/css">
# </style>
# <table id="T_deb06">
#   <thead>
#     <tr>
#       <th id="T_deb06_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_deb06_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_deb06_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_deb06_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_deb06_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_deb06_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_deb06_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_deb06_row0_col1" class="data row0 col1" >plan_recorder</td>
#       <td id="T_deb06_row0_col2" class="data row0 col2" >0.00152</td>
#       <td id="T_deb06_row0_col3" class="data row0 col3" >5106</td>
#       <td id="T_deb06_row0_col4" class="data row0 col4" >1251</td>
#       <td id="T_deb06_row0_col5" class="data row0 col5" >6357</td>
#     </tr>
#   </tbody>
# </table>
# Message from plan_recorder:
# Planning stage complete. Switching to control.
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_79175">
#   <thead>
#     <tr>
#       <th id="T_79175_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_79175_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_79175_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_79175_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_79175_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_79175_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_79175_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_79175_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_79175_row0_col2" class="data row0 col2" >0.01508</td>
#       <td id="T_79175_row0_col3" class="data row0 col3" >5634</td>
#       <td id="T_79175_row0_col4" class="data row0 col4" >99</td>
#       <td id="T_79175_row0_col5" class="data row0 col5" >5733</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# **Step number:** 1 out of 6.
#
# **Sub-task:** Provide theoretical background on the linear matter power spectrum and neural network approaches in cosmology.
#
# **Agent in charge of sub-task:** `researcher`
#
# **Instructions:**
#
# - Summarize the theoretical background of the linear matter power spectrum.
# - Review neural network architectures that have been successful in cosmology applications.
# - Provide guidance on potential architectures to consider for this task.
#
# **Status:** in progress ⏳
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_220aa">
#   <thead>
#     <tr>
#       <th id="T_220aa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_220aa_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_220aa_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_220aa_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_220aa_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_220aa_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_220aa_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_220aa_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_220aa_row0_col2" class="data row0 col2" >0.01490</td>
#       <td id="T_220aa_row0_col3" class="data row0 col3" >5899</td>
#       <td id="T_220aa_row0_col4" class="data row0 col4" >15</td>
#       <td id="T_220aa_row0_col5" class="data row0 col5" >5914</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# Transitioning to researcher!
# Calling researcher...
# <style type="text/css">
# </style>
# <table id="T_bb063">
#   <thead>
#     <tr>
#       <th id="T_bb063_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bb063_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_bb063_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_bb063_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_bb063_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_bb063_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bb063_row0_col0" class="data row0 col0" >gemini-2.0-pro-exp-02-05</td>
#       <td id="T_bb063_row0_col1" class="data row0 col1" >researcher</td>
#       <td id="T_bb063_row0_col2" class="data row0 col2" >0.00156</td>
#       <td id="T_bb063_row0_col3" class="data row0 col3" >5965</td>
#       <td id="T_bb063_row0_col4" class="data row0 col4" >2417</td>
#       <td id="T_bb063_row0_col5" class="data row0 col5" >8382</td>
#     </tr>
#   </tbody>
# </table>
# Message from researcher:
# Forwarding content for formatting...
# Calling researcher_response_formatter...
# <style type="text/css">
# </style>
# <table id="T_3202e">
#   <thead>
#     <tr>
#       <th id="T_3202e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3202e_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_3202e_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_3202e_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_3202e_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_3202e_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3202e_row0_col0" class="data row0 col0" >gpt-4o-mini-2024-07-18</td>
#       <td id="T_3202e_row0_col1" class="data row0 col1" >researcher_response_formatter</td>
#       <td id="T_3202e_row0_col2" class="data row0 col2" >0.00258</td>
#       <td id="T_3202e_row0_col3" class="data row0 col3" >7162</td>
#       <td id="T_3202e_row0_col4" class="data row0 col4" >2505</td>
#       <td id="T_3202e_row0_col5" class="data row0 col5" >9667</td>
#     </tr>
#   </tbody>
# </table>
# Message from researcher_response_formatter:
#
# **Markdown:**
#
# ```markdown
# <!-- filename: linear_matter_power_spectrum_theory.md -->
# ### Linear Matter Power Spectrum: Theoretical Background
#
# The linear matter power spectrum, denoted as P(k), is a fundamental quantity in cosmology that describes the distribution of matter in the Universe as a function of scale. It quantifies the amplitude of density fluctuations at different wavenumbers (k), which are inversely proportional to spatial scales. Here's a breakdown:
#
# 1. **Density Fluctuations:** In the early Universe, tiny quantum fluctuations existed. These fluctuations, amplified by gravity over cosmic time, led to the formation of the large-scale structures we observe today (galaxies, clusters, etc.). We describe these fluctuations using the density contrast:
#
#    $$\delta(\mathbf{x}) = \frac{\rho(\mathbf{x}) - \bar{\rho}}{\bar{\rho}}$$
#
#    where $\rho(\mathbf{x})$ is the matter density at a point $\mathbf{x}$, and $\bar{\rho}$ is the average matter density of the Universe.
#
# 2. **Fourier Space:** It's mathematically convenient to analyze these density fluctuations in Fourier space. The Fourier transform of the density contrast is:
#
#    $$\delta(\mathbf{k}) = \int d^3x \, \delta(\mathbf{x}) e^{-i\mathbf{k}\cdot\mathbf{x}}$$
#
#    where $\mathbf{k}$ is the wavevector, and $k = |\mathbf{k}|$ is the wavenumber. Each $\delta(\mathbf{k})$ represents the amplitude of a density fluctuation with a specific wavelength (related to 1/k).
#
# 3. **Statistical Homogeneity and Isotropy:** A core assumption of the standard cosmological model is that the Universe is statistically homogeneous and isotropic on large scales. This means the statistical properties of the density fluctuations are the same everywhere and in all directions. This simplifies the analysis considerably.
#
# 4. **Power Spectrum Definition:** The power spectrum, P(k), is defined as the variance of the density fluctuations in Fourier space:
#
#    $$ \langle \delta(\mathbf{k}) \delta^*(\mathbf{k}') \rangle = (2\pi)^3 \delta_D(\mathbf{k} - \mathbf{k}') P(k) $$
#
#    where:
#    * $\langle ... \rangle$ denotes an ensemble average (average over many realizations of the Universe, or equivalently, over different regions of our Universe, assuming ergodicity).
#    * $\delta^*(\mathbf{k}')$ is the complex conjugate of $\delta(\mathbf{k}')$.
#    * $\delta_D(\mathbf{k} - \mathbf{k}')$ is the Dirac delta function, which enforces that different Fourier modes are uncorrelated (a consequence of statistical homogeneity and isotropy). This means that the power spectrum only depends on the magnitude of the wavevector, *k*, not its direction.
#
# 5. **Linear Regime:** The *linear* matter power spectrum refers to the power spectrum during the epoch when density fluctuations are small ($\delta << 1$). In this regime, the evolution of the density fluctuations can be described by linear perturbation theory, which simplifies the calculations significantly. Non-linear effects become important at later times and on smaller scales.
#
# 6. **Primordial Power Spectrum:** The shape of the linear matter power spectrum is determined by two main factors: the primordial power spectrum and the growth of structure. The primordial power spectrum, $P_i(k)$, describes the initial conditions of the density fluctuations, often assumed to be a power-law:
#
#    $$P_i(k) \propto k^{n_s}$$
#
#    where $n_s$ is the scalar spectral index (close to 1 in most inflationary models).
#
# 7. **Growth of Structure:** The primordial fluctuations grow due to gravitational instability. However, the growth rate depends on the wavenumber, *k*. Modes that enter the horizon (the region of space causally connected at a given time) during the radiation-dominated era are suppressed compared to those that enter during the matter-dominated era. This leads to a characteristic turnover in the power spectrum. The evolution is described by the transfer function, T(k):
#
#    $$P(k) \propto k^{n_s} T^2(k)$$
#
# 8. **Cosmological Parameters:** The precise shape of P(k) is highly sensitive to cosmological parameters, such as the matter density ($\Omega_m$), the dark energy density ($\Omega_\Lambda$), the Hubble constant ($H_0$), the baryon density ($\Omega_b$), and the scalar spectral index ($n_s$). By measuring P(k) from observations (e.g., galaxy surveys, cosmic microwave background), we can constrain these parameters.
#
# 9. **Baryon Acoustic Oscillations (BAO):** The linear matter power spectrum exhibits characteristic oscillations known as Baryon Acoustic Oscillations (BAO). These oscillations are imprints of sound waves that propagated in the early Universe before recombination. The scale of these oscillations provides a "standard ruler" for measuring cosmic distances.
#
# ### Neural Network Architectures in Cosmology
#
# Several neural network architectures have proven successful in cosmological applications. Here's a review, with a focus on those relevant to predicting the matter power spectrum:
#
# 1. **Multilayer Perceptrons (MLPs) / Fully Connected Networks:**
#    * **Description:** MLPs consist of multiple layers of interconnected nodes (neurons). Each connection has an associated weight, and each neuron applies an activation function to its weighted input.
#    * **Successes:** MLPs have been used to estimate cosmological parameters from simulated and real data, including power spectra. They are relatively simple to implement and train.
#    * **Relevance:** MLPs are a good starting point for this task due to their simplicity and ability to learn non-linear relationships. They can map cosmological parameters to the corresponding log(P(k)).
#    * **Limitations:** MLPs may not be the most efficient architecture for capturing the complex relationships and features within the power spectrum, especially the BAO features.
#
# 2. **Convolutional Neural Networks (CNNs):**
#    * **Description:** CNNs are designed to process data with a grid-like topology (e.g., images). They use convolutional layers to extract local features and pooling layers to reduce dimensionality.
#    * **Successes:** CNNs have been used in cosmology for tasks like weak lensing analysis, identifying galaxy clusters, and classifying large-scale structures. They excel at extracting features from images and spatial data.
#    * **Relevance:** While the power spectrum is 1D, CNNs can still be applied. The convolutional layers can learn to identify features like the BAO wiggles and the overall shape of the spectrum. Treating the power spectrum as a 1D "image" is a viable approach.
#    * **Limitations:** CNNs might be overkill for 1D data, and their translational invariance property might not be fully utilized.
#
# 3. **Recurrent Neural Networks (RNNs) / LSTMs / GRUs:**
#    * **Description:** RNNs are designed to process sequential data. They have internal memory that allows them to retain information from previous inputs. Long Short-Term Memory (LSTM) and Gated Recurrent Unit (GRU) networks are variants of RNNs that address the vanishing gradient problem.
#    * **Successes:** RNNs have been used in cosmology for time-series analysis, such as analyzing supernova light curves.
#    * **Relevance:** The power spectrum can be viewed as a sequence of values ordered by wavenumber, *k*. RNNs could potentially learn the sequential dependencies and patterns in the power spectrum.
#    * **Limitations:** The inherent ordering in *k* is crucial, but the long-range dependencies might be better captured by other architectures.
#
# 4. **Transformer Networks:**
#    * **Description:** Transformers rely on the self-attention mechanism, which allows the network to weigh the importance of different parts of the input sequence when making predictions. They have become dominant in natural language processing.
#    * **Successes:** Transformers are increasingly being used in cosmology, showing promise in tasks like analyzing galaxy catalogs and predicting cosmological parameters.
#    * **Relevance:** The self-attention mechanism could be very effective at capturing the long-range correlations and subtle features in the power spectrum, including the BAO. Transformers can handle variable-length input, which could be useful if the *k* range varies between samples.
#    * **Limitations:** Transformers can be computationally expensive to train, especially for very long sequences.
#
# 5. **Graph Neural Networks (GNNs):**
#    * **Description:** Designed to process graph data.
#    * **Successes:** Used in cosmology to model galaxy distributions.
#    * **Relevance:** Less relevant for directly processing the 1D power spectrum.
#
# 6. **Implicit Neural Representations (INRs):**
#    * **Description:** INRs parameterize a signal (like an image or a 3D shape) as a continuous function represented by a neural network. The network takes coordinates as input and outputs the signal value at that location.
#    * **Successes:** Used in various fields for representing signals and shapes compactly and efficiently.
#    * **Relevance:** An INR could be used to represent the power spectrum as a continuous function of *k*. The network would take *k* and cosmological parameters as input and output log(P(k)). This approach could be very efficient for evaluation and potentially for interpolation.
#    * **Limitations:** Training INRs can sometimes be challenging, and ensuring smoothness and generalization can require careful design.
#
# ### Guidance on Potential Architectures
#
# For this task, I recommend considering the following two architectures:
#
# 1. **MLP (Baseline):** Start with a simple MLP as a baseline. This will provide a benchmark against which to compare more complex architectures. The input layer should take the cosmological parameters, and the output layer should produce the log(P(k)) values at the specified *k* values. Experiment with the number of hidden layers and neurons per layer.
#
# 2. **Transformer:** A Transformer network is a strong candidate due to its ability to capture long-range dependencies and subtle features using the self-attention mechanism. This is particularly relevant for accurately modeling the BAO wiggles. The input would be the cosmological parameters concatenated with the *k* values (or positional encodings of *k*), and the output would be the corresponding log(P(k)) values.
#
# **Alternative/Additional Considerations:**
#
# * **1D CNN:** A 1D CNN is also a reasonable choice, and it would be worthwhile to compare its performance to the MLP and Transformer.
# * **INR:** Exploring an INR approach could be interesting for its potential efficiency and ability to represent the power spectrum as a continuous function.
#
# **Key Considerations:**
#
# * **Speed:** MLPs are generally very fast to evaluate. Transformers can be slower, but optimized implementations and techniques like model distillation can improve speed.
# * **Accuracy:** The Transformer is likely to achieve the highest accuracy, followed by the 1D CNN, and then the MLP.
# * **Complexity:** MLPs are the simplest to implement, while Transformers are the most complex.
#
# By implementing and comparing both an MLP and a Transformer, we can gain a good understanding of the trade-offs between simplicity, speed, and accuracy for this specific task.
# ```
#
# Calling executor...
#
# Message from executor:
#
# execution succeeded
# Execution output: Content saved to /Users/boris/CMBAgents/cmbagent/output/linear_matter_power_spectrum_theory.md
#
#
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_1d3c4">
#   <thead>
#     <tr>
#       <th id="T_1d3c4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1d3c4_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_1d3c4_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_1d3c4_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_1d3c4_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_1d3c4_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d3c4_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_1d3c4_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_1d3c4_row0_col2" class="data row0 col2" >0.02798</td>
#       <td id="T_1d3c4_row0_col3" class="data row0 col3" >10799</td>
#       <td id="T_1d3c4_row0_col4" class="data row0 col4" >98</td>
#       <td id="T_1d3c4_row0_col5" class="data row0 col5" >10897</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# **Step number:** 1 out of 6.
#
# **Sub-task:** Provide theoretical background on the linear matter power spectrum and neural network approaches in cosmology.
#
# **Agent in charge of sub-task:** `researcher`
#
# **Instructions:**
#
# - Summarize the theoretical background of the linear matter power spectrum.
# - Review neural network architectures that have been successful in cosmology applications.
# - Provide guidance on potential architectures to consider for this task.
#
# **Status:** completed ✅
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_896ef">
#   <thead>
#     <tr>
#       <th id="T_896ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_896ef_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_896ef_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_896ef_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_896ef_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_896ef_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_896ef_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_896ef_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_896ef_row0_col2" class="data row0 col2" >0.02878</td>
#       <td id="T_896ef_row0_col3" class="data row0 col3" >11004</td>
#       <td id="T_896ef_row0_col4" class="data row0 col4" >127</td>
#       <td id="T_896ef_row0_col5" class="data row0 col5" >11131</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# **Step number:** 2 out of 6.
#
# **Sub-task:** Gather information on the classy_sz package and its potential use for generating the linear matter power spectrum.
#
# **Agent in charge of sub-task:** `classy_sz_agent`
#
# **Instructions:**
#
# - Search for information on the classy_sz package to understand its capabilities and how it can be used to generate the linear matter power spectrum.
# - Identify if it can be used to generate the training and testing datasets (500 spectra for training and 50 for testing).
# - Provide a summary of findings and any relevant implementation details.
#
# **Status:** in progress ⏳
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_c7d66">
#   <thead>
#     <tr>
#       <th id="T_c7d66_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c7d66_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_c7d66_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_c7d66_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_c7d66_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_c7d66_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7d66_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_c7d66_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_c7d66_row0_col2" class="data row0 col2" >0.02841</td>
#       <td id="T_c7d66_row0_col3" class="data row0 col3" >11299</td>
#       <td id="T_c7d66_row0_col4" class="data row0 col4" >16</td>
#       <td id="T_c7d66_row0_col5" class="data row0 col5" >11315</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# Transitioning to classy_sz_agent!
# Calling classy_sz_agent...
# <style type="text/css">
# </style>
# <table id="T_bde11">
#   <thead>
#     <tr>
#       <th id="T_bde11_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bde11_level0_col1" class="col_heading level0 col1" >Cost</th>
#       <th id="T_bde11_level0_col2" class="col_heading level0 col2" >Prompt Tokens</th>
#       <th id="T_bde11_level0_col3" class="col_heading level0 col3" >Completion Tokens</th>
#       <th id="T_bde11_level0_col4" class="col_heading level0 col4" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bde11_row0_col0" class="data row0 col0" >gpt-4o-mini</td>
#       <td id="T_bde11_row0_col1" class="data row0 col1" >0.00376</td>
#       <td id="T_bde11_row0_col2" class="data row0 col2" >21886</td>
#       <td id="T_bde11_row0_col3" class="data row0 col3" >798</td>
#       <td id="T_bde11_row0_col4" class="data row0 col4" >22684</td>
#     </tr>
#   </tbody>
# </table>
# Message from classy_sz_agent:
# Forwarding content for formatting...
# Calling classy_sz_response_formatter...
# <style type="text/css">
# </style>
# <table id="T_7eeab">
#   <thead>
#     <tr>
#       <th id="T_7eeab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7eeab_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_7eeab_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_7eeab_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_7eeab_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_7eeab_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7eeab_row0_col0" class="data row0 col0" >gpt-4o-2024-08-06</td>
#       <td id="T_7eeab_row0_col1" class="data row0 col1" >classy_sz_response_formatter</td>
#       <td id="T_7eeab_row0_col2" class="data row0 col2" >0.03309</td>
#       <td id="T_7eeab_row0_col3" class="data row0 col3" >11007</td>
#       <td id="T_7eeab_row0_col4" class="data row0 col4" >557</td>
#       <td id="T_7eeab_row0_col5" class="data row0 col5" >11564</td>
#     </tr>
#   </tbody>
# </table>
# Message from classy_sz_response_formatter:
# **File Search Task:**
#
# The classy_sz package is designed for cosmological computations, including the generation of the linear matter power spectrum. Here are the key findings regarding its capabilities:
#
# 1. **Initialization and Setup:**
#    - The package requires initialization through the `Class_sz()` structure, where cosmological parameters are set using the `set` method. The output can be specified to include the matter power spectrum by using `'output':'mPk'` .
#
# 2. **Computing the Linear Matter Power Spectrum:**
#    - After initializing the package, the linear matter power spectrum can be computed at a specific redshift (z) using the method `get_pkl_at_z(z, params_values_dict=cosmo_params)`, where `cosmo_params` includes necessary cosmological parameters such as matter density, Hubble constant, and scalar spectral index .
#
# 3. **Generating Datasets:**
#    - The package can generate the required training and testing datasets (500 spectra for training and 50 for testing) by varying the cosmological parameters and redshift values. This allows for sufficient diversity in the datasets .
#
# 4. **Output Format:**
#    - The output of the computations can be saved in a format suitable for training neural networks, specifically in the form of log(P(k)) .
#
# **File Consulted:**
#
# classy_sz_matter_power_spectrum.md
#
# **Results:**
#
# The classy_sz package is capable of generating the linear matter power spectrum and can be used to create diverse training and testing datasets by varying cosmological parameters and redshift values. The output can be formatted as log(P(k)) for neural network training.
#
#
# **Python Code:**
#
# ```python
# import numpy as np
# from classy_sz import Class as Class_sz
#
# # Initialize the Class_sz object
# classy_sz = Class_sz()
# classy_sz.set({
#     'output': 'mPk',  # Request the matter power spectrum
# })
# classy_sz.initialize_classy_szfast()  # Crucial initialization step
#
# # Define cosmological parameters
# cosmo_params = {
#     'omega_b': 0.02242,
#     'omega_cdm': 0.11933,
#     'H0': 67.66,
#     'tau_reio': 0.0561,
#     'ln10^{10}A_s': 3.047,
#     'n_s': 0.9665,
# }
#
# # Choose a redshift value
# z = 0.3
#
# # Compute the linear matter power spectrum
# pks, ks = classy_sz.get_pkl_at_z(z, params_values_dict=cosmo_params)
# ```
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_77e67">
#   <thead>
#     <tr>
#       <th id="T_77e67_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_77e67_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_77e67_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_77e67_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_77e67_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_77e67_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_77e67_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_77e67_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_77e67_row0_col2" class="data row0 col2" >0.03284</td>
#       <td id="T_77e67_row0_col3" class="data row0 col3" >12632</td>
#       <td id="T_77e67_row0_col4" class="data row0 col4" >126</td>
#       <td id="T_77e67_row0_col5" class="data row0 col5" >12758</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# **Step number:** 2 out of 6.
#
# **Sub-task:** Gather information on the classy_sz package and its potential use for generating the linear matter power spectrum.
#
# **Agent in charge of sub-task:** `classy_sz_agent`
#
# **Instructions:**
#
# - Search for information on the classy_sz package to understand its capabilities and how it can be used to generate the linear matter power spectrum.
# - Identify if it can be used to generate the training and testing datasets (500 spectra for training and 50 for testing).
# - Provide a summary of findings and any relevant implementation details.
#
# **Status:** completed ✅
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_4833c">
#   <thead>
#     <tr>
#       <th id="T_4833c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4833c_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_4833c_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_4833c_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_4833c_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_4833c_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4833c_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_4833c_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_4833c_row0_col2" class="data row0 col2" >0.03349</td>
#       <td id="T_4833c_row0_col3" class="data row0 col3" >12893</td>
#       <td id="T_4833c_row0_col4" class="data row0 col4" >126</td>
#       <td id="T_4833c_row0_col5" class="data row0 col5" >13019</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# **Step number:** 3 out of 6.
#
# **Sub-task:** Generate the training and testing datasets for the linear matter power spectrum.
#
# **Agent in charge of sub-task:** `engineer`
#
# **Instructions:**
#
# - Use the classy_sz package (or an alternative if necessary) to generate 500 spectra for training and 50 spectra for testing.
# - Ensure sufficient diversity in the datasets by sampling the parameter space effectively.
# - Ensure the data is in the form of log(pk) for training purposes.
# - Save the datasets in a format suitable for training neural networks.
#
# **Status:** in progress ⏳
# Calling control...
# <style type="text/css">
# </style>
# <table id="T_d624e">
#   <thead>
#     <tr>
#       <th id="T_d624e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d624e_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_d624e_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_d624e_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_d624e_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_d624e_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d624e_row0_col0" class="data row0 col0" >gpt-4o-2024-11-20</td>
#       <td id="T_d624e_row0_col1" class="data row0 col1" >control</td>
#       <td id="T_d624e_row0_col2" class="data row0 col2" >0.03303</td>
#       <td id="T_d624e_row0_col3" class="data row0 col3" >13155</td>
#       <td id="T_d624e_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_d624e_row0_col5" class="data row0 col5" >13169</td>
#     </tr>
#   </tbody>
# </table>
# Message from control:
# Transitioning to engineer!
# Calling engineer...
# <style type="text/css">
# </style>
# <table id="T_0cc27">
#   <thead>
#     <tr>
#       <th id="T_0cc27_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0cc27_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_0cc27_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_0cc27_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_0cc27_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
#       <th id="T_0cc27_level0_col5" class="col_heading level0 col5" >Total Tokens</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0cc27_row0_col0" class="data row0 col0" >o3-mini-2025-01-31</td>
#       <td id="T_0cc27_row0_col1" class="data row0 col1" >engineer</td>
#       <td id="T_0cc27_row0_col2" class="data row0 col2" >0.03700</td>
#       <td id="T_0cc27_row0_col3" class="data row0 col3" >13189</td>
# ...
#
#     # Determine best architecture based on performance and inference speed
#     if mlp_mse < transformer_mse and mlp_inference_time < transformer_inference_time:
#         best_architecture = "MLP"
#     elif transformer_mse < mlp_mse and transformer_inference_time < mlp_inference_time:
#         best_architecture = "Transformer"
#     else:
#         best_architecture = "MLP" if mlp_mse < transformer_mse else "Transformer"
#
#     print("Best architecture based on performance and speed:", best_architecture)
#
# if __name__ == "__main__":
#     main()
# ```
# Calling executor...
#
# Message from executor:
#
# execution succeeded
# Execution output: WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# MLP Model Test MSE: 0.053447574581354795
# MLP Model Maximum Relative Error: 240.00065116009452
# MLP Model Average Inference Time per Sample (s): 0.0011576725007034839
# Transformer Model Test MSE: 0.7441852659254901
# Transformer Model Maximum Relative Error: 545.4377771278878
# Transformer Model Average Inference Time per Sample (s): 0.007909574999939651
# Predicted vs True power spectra plot saved to data/predicted_vs_true.png
# Best architecture based on performance and speed: MLP
#
#
# Calling control...
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 10
#       1 task = r"""
#       2 Develop and Train neural nets for the linear matter power spectrum using 2 different architectures that you think would work well.
#       3 We need the networks to be very accurate and precise, but also we want them to be fast to evaluate.
#    (...)
#       8 Plot predicted vs true Pks (use log scales in both x and y axes).
#       9 """
# ---> 10 cmbagent.solve(task,
#      11                max_rounds=100,
#      12                shared_context = {'feedback_left': 1,
#      13                                  'maximum_number_of_steps_in_plan': 5})
#
# File ~/CMBAgents/cmbagent/cmbagent/cmbagent.py:561, in CMBAgent.solve(self, task, initial_agent, shared_context, max_rounds)
#     557     agent.agent.reset()
#     559 this_shared_context['main_task'] = task
# --> 561 chat_result, context_variables, last_agent = initiate_swarm_chat(
#     562     initial_agent=self.get_agent_from_name(initial_agent),
#     563     agents=[agent.agent for agent in self.agents],
#     564     messages=this_shared_context['main_task'],
#     565     user_agent=self.get_agent_from_name("admin"),
#     566     context_variables=this_shared_context,
#     567     max_rounds = max_rounds,
#     568     after_work=AfterWorkOption.REVERT_TO_USER,
#     569 )
#     572 self.final_context = copy.deepcopy(context_variables)
#     574 self.last_agent = last_agent
#
# File ~/CMBAgents/ag2/autogen/agentchat/contrib/swarm_agent.py:697, in initiate_swarm_chat(initial_agent, messages, agents, user_agent, swarm_manager_args, max_rounds, context_variables, after_work)
#     694     last_message = processed_messages[0]
#     695     clear_history = True
# --> 697 chat_result = last_agent.initiate_chat(
#     698     manager,
#     699     message=last_message,
#     700     clear_history=clear_history,
#     701 )
#     703 _cleanup_temp_user_messages(chat_result)
#     705 return chat_result, context_variables, manager.last_speaker
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:1543, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1541     else:
#    1542         msg2send = self.generate_init_message(message, **kwargs)
# -> 1543     self.send(msg2send, recipient, silent=silent)
#    1544 summary = self._summarize_chat(
#    1545     summary_method,
#    1546     summary_args,
#    1547     recipient,
#    1548     cache=cache,
#    1549 )
#    1550 for agent in [self, recipient]:
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:1214, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1212 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1213 if valid:
# -> 1214     recipient.receive(message, self, request_reply, silent)
#    1215 else:
#    1216     raise ValueError(
#    1217         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1218     )
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:1335, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1333 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1334     return
# -> 1335 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1336 if reply is not None:
#    1337     self.send(reply, sender, silent=silent)
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:2670, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2663 # Check if this function should be triggered for this sender
#    2664 if self._match_trigger(reply_func_tuple["trigger"], sender):
#    2665     # print(f"Trigger matched for {reply_func.__name__}, executing...")
#    2666
#    2667     # Execute the reply function
#    2668     # print("\n in conversable_agent.py generate_reply reply_func_tuple:")
#    2669     # print(json.dumps(reply_func_tuple, indent=4, default=str))
# -> 2670     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2671     # print(f"s final={final}, reply={reply}")
#    2672
#    2673     # Log the execution if logging is enabled
#    2674     if logging_enabled():
#    2675         # print("Logging reply function execution")
#
# File ~/CMBAgents/ag2/autogen/agentchat/groupchat.py:1345, in GroupChatManager.run_chat(self, messages, sender, config)
#    1343         print("\n in groupchat.py generate_reply....")
#    1344         print("\n\n\n-----------------------------------\n")
# -> 1345     reply = speaker.generate_reply(sender=self)
#    1346     # print("\n\n\n-----------------------------------\n")
#    1347     # print("\n in groupchat.py reply: ", reply)
#    1348     # print("\n\n\n-----------------------------------\n")
#    (...)
#    1351     # import json; print(json.dumps(speaker._context_variables, indent=4))
#    1352     # import sys; sys.exit()
#    1353 except KeyboardInterrupt:
#    1354     # let the admin agent speak if interrupted
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:2670, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2663 # Check if this function should be triggered for this sender
#    2664 if self._match_trigger(reply_func_tuple["trigger"], sender):
#    2665     # print(f"Trigger matched for {reply_func.__name__}, executing...")
#    2666
#    2667     # Execute the reply function
#    2668     # print("\n in conversable_agent.py generate_reply reply_func_tuple:")
#    2669     # print(json.dumps(reply_func_tuple, indent=4, default=str))
# -> 2670     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2671     # print(f"s final={final}, reply={reply}")
#    2672
#    2673     # Log the execution if logging is enabled
#    2674     if logging_enabled():
#    2675         # print("Logging reply function execution")
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:1864, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1860     messages = self._oai_messages[sender]
#    1861 # cmbagent debug
#    1862 # print('in conversable_agent.py generate_oai_reply( messages: ',  self._oai_system_message + messages)
#    1863 # print('in conversable_agent.py generate_oai_reply( client_cache: ', self.client_cache)
# -> 1864 extracted_response = self._generate_oai_reply_from_client(
#    1865     client, self._oai_system_message + messages, self.client_cache)
#    1866 # print('in conversable_agent.py generate_oai_reply extracted_response: ', extracted_response)
#    1868 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~/CMBAgents/ag2/autogen/agentchat/conversable_agent.py:1923, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1914     response = llm_client.create(
#    1915         context=messages[-1].pop("context", None),
#    1916         messages=all_messages,
#    (...)
#    1920         tool_choice=tool_choice
#    1921     )
#    1922 except:
# -> 1923     response = llm_client.create(
#    1924         context=messages[-1].pop("context", None),
#    1925         messages=all_messages,
#    1926         cache=cache,
#    1927         agent=self
#    1928     )
#    1929 ## cmbagent modif print to help debug:
#    1930 # print full raw response here
#    1931 # cmbagent debug
#    (...)
#    1936 # llm_client.print_usage_summary(mode="actual")  # print actual usage summary, i.e., excluding cached usage
#    1937 # Update dictionary containing all costs
#    1938 usage_summary = llm_client.return_usage_summary(mode="actual")
#
# File ~/CMBAgents/ag2/autogen/oai/client.py:1123, in OpenAIWrapper.create(self, **config)
#    1118     # import sys
#    1119     # sys.exit()
#    1122 request_ts = get_current_ts()
# -> 1123 response = client.create(params)
#    1124 # cmbagent debug
#    1125 if cmbagent_debug:
#
# File ~/CMBAgents/ag2/autogen/oai/client.py:570, in OpenAIClient.create(self, params)
#     554 params["stream"] = False
#     556 ### start of cmbagent changes for structured output for summary agents by hand. Not
#     557 ### formatted output for cmbagent
#     558 ## call the oai client with the response_format
#    (...)
#     566 # print('----> now creating response')
#     567 ### end of cmbagent changes.
# --> 570 response = create_or_parse(**params)
#     571 # remove the system_message from the response and add it in the prompt at the start.
#     572 if is_o1:
#
# File ~/CMBAgents/ag2/autogen/oai/client.py:372, in OpenAIClient._handle_openai_bad_request_error.<locals>.wrapper(*args, **kwargs)
#     364     error_message = (
#     365         f"This error typically occurs when the agent name contains invalid characters, such as spaces or special symbols.\n"
#     366         "Please ensure that your agent name follows the correct format and doesn't include any unsupported characters.\n"
#     367         "Check the agent name and try again.\n"
#     368         f"Here is the full BadRequestError from openai:\n{e.message}."
#     369     )
#     370     raise ValueError(error_message)
# --> 372 raise e
#
# File ~/CMBAgents/ag2/autogen/oai/client.py:355, in OpenAIClient._handle_openai_bad_request_error.<locals>.wrapper(*args, **kwargs)
#     353 try:
#     354     kwargs = OpenAIClient._patch_messages_for_deepseek_reasoner(**kwargs)
# --> 355     return func(*args, **kwargs)
#     356 except openai.BadRequestError as e:
#     357     response_json = e.response.json()
#
# File ~/venvdir/class_sz_312_brew/lib/python3.12/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/venvdir/class_sz_312_brew/lib/python3.12/site-packages/openai/resources/chat/completions.py:859, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     817 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     818 def create(
#     819     self,
#    (...)
#     856     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     857 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858     validate_response_format(response_format)
# --> 859     return self._post(
#     860         "/chat/completions",
#     861         body=maybe_transform(
#     862             {
#     863                 "messages": messages,
#     864                 "model": model,
#     865                 "audio": audio,
#     866                 "frequency_penalty": frequency_penalty,
#     867                 "function_call": function_call,
#     868                 "functions": functions,
#     869                 "logit_bias": logit_bias,
#     870                 "logprobs": logprobs,
#     871                 "max_completion_tokens": max_completion_tokens,
#     872                 "max_tokens": max_tokens,
#     873                 "metadata": metadata,
#     874                 "modalities": modalities,
#     875                 "n": n,
#     876                 "parallel_tool_calls": parallel_tool_calls,
#     877                 "prediction": prediction,
#     878                 "presence_penalty": presence_penalty,
#     879                 "reasoning_effort": reasoning_effort,
#     880                 "response_format": response_format,
#     881                 "seed": seed,
#     882                 "service_tier": service_tier,
#     883                 "stop": stop,
#     884                 "store": store,
#     885                 "stream": stream,
#     886                 "stream_options": stream_options,
#     887                 "temperature": temperature,
#     888                 "tool_choice": tool_choice,
#     889                 "tools": tools,
#     890                 "top_logprobs": top_logprobs,
#     891                 "top_p": top_p,
#     892                 "user": user,
#     893             },
#     894             completion_create_params.CompletionCreateParams,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ChatCompletion,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ChatCompletionChunk],
#     902     )
#
# File ~/venvdir/class_sz_312_brew/lib/python3.12/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/venvdir/class_sz_312_brew/lib/python3.12/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/venvdir/class_sz_312_brew/lib/python3.12/site-packages/openai/_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 128000 tokens. However, your messages resulted in 128717 tokens (128344 in the messages, 373 in the functions). Please reduce the length of the messages or functions.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}

# %%
# filename: codebase/compare_architectures.py
import numpy as np
import os
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Enable LaTeX rendering and set font properties for plotting
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'

def load_dataset(file_path):
    r"""
    Load dataset from an NPZ file.

    Args:
        file_path (str): Path to the NPZ file containing the dataset.

    Returns:
        tuple: Tuple containing arrays:
            - params (np.ndarray): Cosmological parameters (shape: [num_samples, 6])
            - zs (np.ndarray): Redshift values (shape: [num_samples,])
            - log_pks (np.ndarray): Natural logarithm of the power spectra (shape: [num_samples, num_k])
            - ks (np.ndarray): Wavenumber grid (shape: [num_k,])
    """
    data = np.load(file_path)
    params = data['params']
    zs = data['zs']
    log_pks = data['log_pks']
    ks = data['ks']
    return params, zs, log_pks, ks

def prepare_transformer_data(params, zs, log_pks, ks):
    r"""
    Prepare input features and targets for the transformer model.

    For each sample, a sequence of tokens is formed with length equal to the number
    of k values. Each token is constructed by concatenating the k value with the constant
    cosmological features (parameters and redshift) for that sample.

    Args:
        params (np.ndarray): Array of cosmological parameters (shape: [num_samples, 6]).
        zs (np.ndarray): Array of redshift values (shape: [num_samples,]).
        log_pks (np.ndarray): Array of log-transformed power spectra (shape: [num_samples, num_k]).
        ks (np.ndarray): Array of wavenumber values (shape: [num_k,]).

    Returns:
        tuple: (X_seq, Y_seq) where:
            - X_seq (np.ndarray): Input sequence for the transformer of shape (num_samples, num_k, 8),
                                  each token is [k, param1, ..., param6, z].
            - Y_seq (np.ndarray): Target sequence with shape (num_samples, num_k, 1).
    """
    n_samples = params.shape[0]
    num_k = ks.shape[0]
    X_base = np.concatenate([params, zs.reshape(-1, 1)], axis=1)  # shape: (n_samples, 7)
    X_base_rep = np.repeat(X_base[:, np.newaxis, :], num_k, axis=1)  # shape: (n_samples, num_k, 7)
    ks_rep = np.tile(ks.reshape(1, num_k, 1), (n_samples, 1, 1))      # shape: (n_samples, num_k, 1)
    X_seq = np.concatenate([ks_rep, X_base_rep], axis=2)              # shape: (n_samples, num_k, 8)
    Y_seq = log_pks[..., np.newaxis]                                  # shape: (n_samples, num_k, 1)
    return X_seq, Y_seq

def main():
    r"""
    Main function to compare the two neural network architectures (MLP and Transformer)
    for predicting the linear matter power spectrum. The script performs:
      1. Loading the testing dataset.
      2. Loading the trained models (using a custom_objects dictionary to resolve 'mse').
      3. Preparing proper inputs for each model.
      4. Benchmarking inference speed.
      5. Computing test MSE and maximum relative error.
      6. Plotting predicted vs true power spectra (on log scales).
      7. Determining and reporting the best architecture.
      8. Saving the plot to disk.
    """
    # Set seeds for reproducibility
    np.random.seed(42)
    tf.random.set_seed(42)
    
    data_dir = "/Users/boris/CMBAgents/cmbagent/output/data"
    test_file = os.path.join(data_dir, "testing_dataset.npz")
    test_params, test_zs, test_log_pks, ks = load_dataset(test_file)
    
    # Prepare input for MLP: concatenate cosmological parameters and redshift (shape: [num_samples, 7])
    X_test_mlp = np.concatenate([test_params, test_zs.reshape(-1, 1)], axis=1)
    
    # Specify custom_objects for model loading to resolve 'mse'
    # Using MeanSquaredError instance instead of tf.keras.losses.mean_squared_error
    custom_objects = {'mse': tf.keras.losses.MeanSquaredError()}
    mlp_model_path = os.path.join(data_dir, "mlp_model.h5")
    transformer_model_path = os.path.join(data_dir, "transformer_model.keras")
    mlp_model = tf.keras.models.load_model(mlp_model_path, custom_objects=custom_objects)
    transformer_model = tf.keras.models.load_model(transformer_model_path, custom_objects=custom_objects)
    
    # Prepare Transformer input data
    X_test_seq, Y_test_seq = prepare_transformer_data(test_params, test_zs, test_log_pks, ks)
    
    n_test = X_test_mlp.shape[0]
    
    # Benchmark inference time for MLP
    start_time = time.perf_counter()
    mlp_pred = mlp_model.predict(X_test_mlp, batch_size=32, verbose=0)
    end_time = time.perf_counter()
    mlp_inference_time = (end_time - start_time) / n_test
    
    # Benchmark inference time for Transformer
    start_time = time.perf_counter()
    transformer_pred = transformer_model.predict(X_test_seq, batch_size=32, verbose=0)
    end_time = time.perf_counter()
    transformer_inference_time = (end_time - start_time) / n_test
    
    # Compute performance metrics for MLP
    mlp_mse = np.mean((mlp_pred - test_log_pks)**2)
    mlp_max_rel_error = np.max(np.abs((mlp_pred - test_log_pks) / (np.abs(test_log_pks) + 1e-7)))
    
    # Process Transformer predictions: remove last dimension
    transformer_pred = np.squeeze(transformer_pred, axis=-1)  # shape: (n_test, num_k)
    transformer_mse = np.mean((transformer_pred - test_log_pks)**2)
    transformer_max_rel_error = np.max(np.abs((transformer_pred - test_log_pks) / (np.abs(test_log_pks) + 1e-7)))
    
    print("MLP Model Test MSE:", mlp_mse)
    print("MLP Model Maximum Relative Error:", mlp_max_rel_error)
    print("MLP Model Average Inference Time per Sample (s):", mlp_inference_time)
    
    print("Transformer Model Test MSE:", transformer_mse)
    print("Transformer Model Maximum Relative Error:", transformer_max_rel_error)
    print("Transformer Model Average Inference Time per Sample (s):", transformer_inference_time)
    
    # Plot predicted vs true power spectra for one test sample (here the first sample)
    sample_idx = 0
    true_log_pk = test_log_pks[sample_idx]   # shape: (num_k,)
    ks_values = ks                          # shape: (num_k,)
    mlp_pred_sample = mlp_pred[sample_idx]    # shape: (num_k,)
    transformer_pred_sample = transformer_pred[sample_idx]  # shape: (num_k,)
    
    # Convert from log space to original power spectra
    true_pk = np.exp(true_log_pk)
    mlp_pk = np.exp(mlp_pred_sample)
    transformer_pk = np.exp(transformer_pred_sample)
    
    # Create subplots for visualization
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Plot for MLP model
    axes[0].set_title("MLP Model")
    axes[0].loglog(ks_values, true_pk, label="True", marker="o", linestyle="-")
    axes[0].loglog(ks_values, mlp_pk, label="Predicted", marker="x", linestyle="--")
    axes[0].set_xlabel(r"$k$")
    axes[0].set_ylabel(r"$P(k)$")
    axes[0].grid(True)
    axes[0].legend()
    axes[0].relim()
    axes[0].autoscale_view()
    
    # Plot for Transformer model
    axes[1].set_title("Transformer Model")
    axes[1].loglog(ks_values, true_pk, label="True", marker="o", linestyle="-")
    axes[1].loglog(ks_values, transformer_pk, label="Predicted", marker="x", linestyle="--")
    axes[1].set_xlabel(r"$k$")
    axes[1].set_ylabel(r"$P(k)$")
    axes[1].grid(True)
    axes[1].legend()
    axes[1].relim()
    axes[1].autoscale_view()
    
    plt.tight_layout()
    plot_path = os.path.join(data_dir, "predicted_vs_true.png")
    plt.savefig(plot_path, dpi=300)
    print("Predicted vs True power spectra plot saved to", plot_path)
    
    # Determine best architecture based on performance and inference speed
    if mlp_mse < transformer_mse and mlp_inference_time < transformer_inference_time:
        best_architecture = "MLP"
    elif transformer_mse < mlp_mse and transformer_inference_time < mlp_inference_time:
        best_architecture = "Transformer"
    else:
        best_architecture = "MLP" if mlp_mse < transformer_mse else "Transformer"
    
    print("Best architecture based on performance and speed:", best_architecture)

if __name__ == "__main__":
    main()
# Out:
# MLP Model Test MSE: 0.053447574581354795
# MLP Model Maximum Relative Error: 240.00065116009452
# MLP Model Average Inference Time per Sample (s): 0.005589080001227558
# Transformer Model Test MSE: 0.7441852659254901
# Transformer Model Maximum Relative Error: 545.4377771278878
# Transformer Model Average Inference Time per Sample (s): 0.00839532915968448
# Predicted vs True power spectra plot saved to /Users/boris/CMBAgents/cmbagent/output/data/predicted_vs_true.png
# Best architecture based on performance and speed: MLP

# %% [markdown]
# ## Context

# %%
cmbagent.shared_context
# Out:
# {'plans': [],
#  'reviews': [],
#  'proposed_plan': None,
#  'recommendations': None,
#  'feedback_left': 1,
#  'number_of_steps_in_plan': None,
#  'maximum_number_of_steps_in_plan': 5,
#  'final_plan': None,
#  'current_plan_step_number': None,
#  'current_sub_task': None,
#  'agent_for_sub_task': None,
#  'current_status': None,
#  'current_instructions': None,
#  'main_task': None,
#  'database_path': 'data/',
#  'codebase_path': 'codebase/',
#  'current_codebase': None,
#  'displayed_images': []}
