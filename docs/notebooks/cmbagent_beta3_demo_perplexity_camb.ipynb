# %% [markdown]
# ## Initialize

# %%
import os
import re
os.environ["CMBAGENT_DEBUG"] = "false"
os.environ["CMBAGENT_DISABLE_DISPLAY"] = "false"

from cmbagent import CMBAgent
# cmbagent = CMBAgent(make_vector_stores='camb')
cmbagent = CMBAgent()
# Out:
#  _____ ___  _________  ___  _____  _____ _   _ _____
# /  __ \|  \/  || ___ \/ _ \|  __ \|  ___| \ | |_   _|
# | /  \/| .  . || |_/ / /_\ \ |  \/| |__ |  \| | | |
# | |    | |\/| || ___ \  _  | | __ |  __|| . ` | | |
# | \__/\| |  | || |_/ / | | | |_\ \| |___| |\  | | |
#  \____/\_|  |_/\____/\_| |_/\____/\____/\_| \_/ \_/
#     multi-agent systems for autonomous discovery
#
# Built with AG2
# Version: Beta3
# Last updated: 11/03/5202

# %%
task = r"""
Search the best-fit planck 2018 cosmological parameters values with perplexity, and then compute and plot cmb temperature cls with camb, setting the cosmological parameters to match what you found with perplexity. 

Provide an animated plot that shows the dependency of cl^TT on the Hubble constant, varying this parameter in a 20-sigma range around the best-fit value. 

- use perplexity, camb_agent and engineer agents
"""

cmbagent.solve(task,
               max_rounds=500,
               # initial_agent='planner',
               shared_context = {'feedback_left': 1,
                                 'maximum_number_of_steps_in_plan': 3}
              )
# Out:
# Message from admin:
# Search the best-fit planck 2018 cosmological parameters values with perplexity, and then compute and plot cmb temperature cls with camb, setting the cosmological parameters to match what you found with perplexity.
#
# Provide an animated plot that shows the dependency of cl^TT on the Hubble constant, varying this parameter in a 20-sigma range around the best-fit value.
#
# - use perplexity, camb_agent and engineer agents
# Calling task_improver...
# <style type="text/css">
# </style>
# <table id="T_2b6a5">
#   <thead>
#     <tr>
#       <th id="T_2b6a5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b6a5_level0_col1" class="col_heading level0 col1" >agent</th>
#       <th id="T_2b6a5_level0_col2" class="col_heading level0 col2" >Cost</th>
#       <th id="T_2b6a5_level0_col3" class="col_heading level0 col3" >Prompt Tokens</th>
#       <th id="T_2b6a5_level0_col4" class="col_heading level0 col4" >Completion Tokens</th>
# ...
